# %% [markdown]
# <a href="https://colab.research.google.com/github/jyotidabass/Image-Processing/blob/main/Types_of_Image.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Monochrome image (Binary Image)**

# %%
import numpy as np

# Create a monochrome image
img = np.zeros((256, 256), dtype=np.uint8)
img[100:200, 100:200] = 255  # Set a white square

import matplotlib.pyplot as plt
plt.imshow(img, cmap='gray')
plt.show()

# %% [markdown]
# # **Grayscale Image**

# %%
import numpy as np
from PIL import Image

# Create a grayscale image
img = np.random.randint(0, 256, size=(256, 256), dtype=np.uint8)

import matplotlib.pyplot as plt
plt.imshow(img, cmap='gray')
plt.show()

# %% [markdown]
# # **Color Image**

# %%
import numpy as np
from PIL import Image

# Create a color image
img = np.random.randint(0, 256, size=(256, 256, 3), dtype=np.uint8)

import matplotlib.pyplot as plt
plt.imshow(img)
plt.show()

# %% [markdown]
# # **Halftone Image**

# %%
import numpy as np
from PIL import Image

# Create a halftone image
img = np.random.randint(0, 256, size=(256, 256), dtype=np.uint8)
halftone_img = np.zeros((256, 256), dtype=np.uint8)

for i in range(256):
    for j in range(256):
        if img[i, j] > 128:
            halftone_img[i, j] = 255
        else:
            halftone_img[i, j] = 0

import matplotlib.pyplot as plt
plt.imshow(halftone_img, cmap='gray')
plt.show()
